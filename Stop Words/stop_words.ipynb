# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spacy's default stop words (Remember)
print(nlp.Defaults.stop_words)
# Out:
# {'over', 'did', 'thereupon', 'call', 'done', 'if', 'would', 'beside', 'from', 'whole', 'may', 'anywhere', 'during', 'cannot', 'here', '‘ve', 'among', 'full', 'anyway', 'very', 'since', 'they', '‘m', 'noone', "'d", 'seeming', 'do', 'nothing', 'her', 'down', 'part', 'whereupon', 'although', 'becomes', 'top', 'nevertheless', 'thence', 'eight', 'various', 'off', 'herein', 'its', 'amount', 'them', 'each', 'up', 'formerly', 'twelve', '‘ll', 'yourselves', 'all', 'except', 'per', 'within', 'any', 'their', 'fifteen', 'him', 'nobody', 'was', 'why', 'being', 'there', '’m', 'my', 'only', 'below', 'one', 'go', 'never', 'either', 'keep', 'due', 'thus', 'well', 'few', 'elsewhere', 'another', 'regarding', 'indeed', 'but', 'am', 'into', '’re', 'fifty', 'wherever', 'mostly', 'someone', 'somewhere', 'whatever', 'beforehand', 'nor', 'everyone', 'behind', 'beyond', 'is', 'yourself', 'seemed', 'i', 'used', 'as', 'further', 'whenever', 'be', 'say', '‘s', 'might', 'these', 'before', 'two', 'whence', 'should', 'towards', 'himself', 'then', 'and', 'us', 'now', 'many', 'does', "'ll", 'amongst', 'none', "'ve", 'the', 'however', 'less', 'who', 'under', 'show', 'became', 'back', 'doing', 'to', 'an', 'everywhere', 'move', 'least', 'nine', 'give', 'own', 'though', 'onto', 'anyone', 'you', 'n’t', 'often', 'thereby', 'wherein', "n't", 'ca', 'seems', 'than', 'always', 'made', 'when', 'in', 'same', 'n‘t', 'eleven', 'using', 'therein', 'again', 'sometimes', 'our', 'could', 'becoming', 'every', 'above', 'name', 'thru', 'have', 'yet', 'that', 'anything', 'ours', 'side', 'whoever', 'not', 'whom', 'this', 'it', 'through', 'myself', 'five', 'perhaps', 'mine', 'he', 'serious', 'together', 'three', 'thereafter', 'anyhow', 'by', 'take', 'hence', 'on', 'while', 'seem', 'even', 'whether', 'otherwise', 'which', 'please', 'hereafter', 'six', "'m", 'his', 'ten', 'whither', 'along', 'get', 'else', 'we', 'alone', 'latterly', 'themselves', 'therefore', 'upon', 'neither', 'last', '’ve', 'so', 'really', 'just', 'until', 'without', 'become', 'much', 'former', 'forty', 'rather', 'ourselves', 'has', 'quite', 'she', 'unless', 'must', 'next', 'how', 'such', "'s", 'once', 'can', 'enough', '‘re', 'herself', 'other', 'of', 'already', 'several', 'ever', 'yours', '’d', 'itself', "'re", 'your', 'also', 'after', 'because', 'been', 'some', 'with', 'others', 'see', 'whereby', 'besides', 'afterwards', 'hers', 'everything', 'across', 'throughout', 'put', 'toward', 'make', 'namely', 'more', 'bottom', 're', 'both', 'out', 'where', 'still', 'first', 'front', 'something', 'too', 'whereafter', 'whose', 'twenty', 'me', 'at', 'moreover', 'empty', 'hereby', 'hundred', 'nowhere', 'almost', 'latter', '‘d', '’ll', 'third', 'meanwhile', 'sixty', 'will', 'sometime', 'hereupon', 'four', 'against', 'whereas', 'most', 'about', 'for', 'a', 'those', 'between', 'or', 'had', 'were', 'what', 'via', 'somehow', '’s', 'no', 'are', 'around'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
# To check if a word is a stop word
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
# To add a stop word
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.vocab['beyond'].is_stop
# Out:
# True

# %%
# To remove a stop_word
# Remove a stop_word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')

# Remove the stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop=False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326
