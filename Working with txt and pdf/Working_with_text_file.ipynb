# %%
#Creating a file with Python

# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# This is the second line of file.
# Out:
# Overwriting test.txt

# %%
my_file=open('test.txt')

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of file.\n'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of file.\n'

# %%
my_file.close()

# %%
my_file=open('test.txt')

# %%
my_file.seek(0)
my_file.readlines(0)
# Out:
# ['Hello, this is a quick test file.\n', 'This is the second line of file.\n']

# %%
my_file.close()

# %%
#      Writing to a file

# %%
my_file=open('test.txt','w+')

# %%
my_file.write('This is the new line in txt file')
# Out:
# 32

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is the new line in txt file'

# %%
my_file.close()

# %%
my_file=open('test.txt','a+')
my_file.write('\nThis line is being append to test.txt')
my_file.write('\nAnd another line here')
# Out:
# 22

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is the new line in txt file\nThis line is being append to test.txt\nAnd another line here'

# %%
my_file=open('test.txt','a+')
my_file.write('\nThis is 4th line')
my_file.write('\nThis is 5th line')
my_file.write('\nThis is 6th line')
# Out:
# 17

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is the new line in txt file\nThis line is being append to test.txt\nAnd another line here\nThis is 4th line\nThis is 5th line\nThis is 6th line'

# %%
#Aliases and context managers
#you can assign temproary variables names as aliases, and manage the opening and cclosing of files automatically using a context manager

# %%
with open('test.txt','r') as txt:
    first_line=txt.readlines()[0]
print(first_line)
# Out:
# This is the new line in txt file

# %%
# %%writefile file1.txt
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Writing file1.txt

# %%
#ITREATING THROUGH A FILE
#the end= "" argument removes extra linebreaks

# %%
with open("test.txt","r") as txt:
    for line in txt:
        print(line,end=' ')
# Out:
# This is the new line in txt file
#  This line is being append to test.txt
#  And another line here
#  This is 4th line
#  This is 5th line
#  This is 6th line
