# %%
import PyPDF2

# %%
f=open('workbook.pdf', 'rb')

# %%
reader=PyPDF2.PdfReader(f)

# %%
reader=PyPDF2.PdfReader(f)

# %%
len(reader.pages)
# Out:
# 7

# %%
page_two=reader.pages[1]

# %%
page_two_text=page_two.extract_text()

# %%
page_two_text
# Out:
# 'TASK 1.1\nMake Your Own Prompt Library\nIn this activity we’ll implement the prompting\ntechniques that we learnt and apply to our\ndaily tasksMastermind Workbook'

# %%
f.close()

# %%
f=open('workbook.pdf', 'rb')
pdf_reader=PyPDF2.PdfReader(f)

# %%
second_page=pdf_reader.pages[1]

# %%
pdf_writer=PyPDF2.PdfWriter(f)

# %%
pdf_writer.add_page(second_page)
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'],
#   '/ExtGState': {'/G3': {'/ca': 1, '/BM': '/Normal'},
#    '/gs2': {'/Type': '/ExtGState', '/ca': 0}},
#   '/XObject': {'/X4': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Width': 565,
#     '/Height': 800,
#     '/ColorSpace': ['/ICCBased', IndirectObject(9, 0, 3111182805472)],
#     '/SMask': {'/Type': '/XObject',
#      '/Subtype': '/Image',
#      '/Width': 565,
#      '/Height': 800,
#      '/ColorSpace': '/DeviceGray',
#      '/BitsPerComponent': 8,
#      '/Filter': '/FlateDecode'},
#     '/BitsPerComponent': 8,
#     '/Filter': '/FlateDecode'}},
#   '/Font': {'/F7': {'/Type': '/Font',
#     '/Subtype': '/Type0',
#     '/BaseFont': '/AAAAAA+Lora-Bold',
#     '/Encoding': '/Identity-H',
#     '/DescendantFonts': [IndirectObject(13, 0, 3111182805472)],
#     '/ToUnicode': {'/Filter': '/FlateDecode'}},
#    '/F8': {'/Type': '/Font',
#     '/Subtype': '/Type0',
#     '/BaseFont': '/BAAAAA+Inter-Regular',
#     '/Encoding': '/Identity-H',
#     '/DescendantFonts': [IndirectObject(19, 0, 3111182805472)],
#     '/ToUnicode': {'/Filter': '/FlateDecode'}},
#    '/F9': {'/Type': '/Font',
#     '/Subtype': '/Type0',
#     '/BaseFont': '/CAAAAA+IBMPlexSans',
#     '/Encoding': '/Identity-H',
#     '/DescendantFonts': [IndirectObject(25, 0, 3111182805472)],
#     '/ToUnicode': {'/Filter': '/FlateDecode'}}}},
#  '/MediaBox': [0, 7.8299813, 595.5, 850.07996],
#  '/Contents': {'/Filter': '/FlateDecode'},
#  '/Tabs': '/S',
#  '/BleedBox': [0, 7.8299813, 595.5, 850.07996],
#  '/TrimBox': [0, 7.8299813, 595.5, 850.07996],
#  '/CropBox': [0, 7.8299813, 595.5, 850.07996],
#  '/Rotate': 0,
#  '/Annots': [],
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 1,
#   '/Kids': [IndirectObject(4, 0, 3111182805472)]}}

# %%
pdf_output=open('New_Doc.pdf','wb')

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='New_Doc.pdf'>)

# %%
pdf_output.close()
f.close()

# %%
f= open('New_Doc.pdf','rb')

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
len(pdf_reader.pages)
# Out:
# 1

# %%
page_one=pdf_reader.pages[0]

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# 'TASK 1.1\nMake Your Own Prompt Library\nIn this activity we’ll implement the prompting\ntechniques that we learnt and apply to our\ndaily tasksMastermind Workbook'

# %%
f=open('workbook.pdf', 'rb')
pdf_text=[]
pdf_reader=PyPDF2.PdfReader(f)
for p in range(len(pdf_reader.pages)):
    page=pdf_reader.pages[p]
    pdf_text.append(page.extract_text())
f.close()

# %%
pdf_text
# Out:
# ['',
#  'TASK 1.1\nMake Your Own Prompt Library\nIn this activity we’ll implement the prompting\ntechniques that we learnt and apply to our\ndaily tasksMastermind Workbook',
#  'Step 1 : Identify Common Tasks\nList daily or routine tasks that can benefit from\nautomation using AI. Examples: writing emails,\nsummarizing documents, scheduling, etc.\nStep 2 : Create Base Prompts for Each Task\nFor each task, develop a basic AI prompt.\nContext: Explain the background of the task.\nTask: State the specific action needed.\nInstruction: Clearly describe how to complete the task.\nData: Identify any data required to perform the task.\nRole: Add a function (e.g., "As a project manager...") to\nenhance prompt accuracy.\nStep 3: Organize the Prompts\nGroup prompts based on categories such as:\nCommunication (e.g., emails, messaging)\nProductivity (e.g., meeting notes, scheduling)\nResearch (e.g., summarizing articles, generating reports)\n  Fill the sheet with your details!FOLLOW THE STEPS TO\nPERFORM THE ACTIVITY:',
#  ' STEP 4:  Refine the Prompts Using Prompting\nTechniques \nZero-Shot Prompting: Start with no examples,\nand let the AI generate output based solely on\nthe instruction. \nFew-Shot Prompting: Provide a few examples to\nguide the AI on how the output should look. \nChain of Thought Prompting: Break down\ncomplex tasks into step-by-step instructions for\nthe AI to follow. \nTree of Thought Prompting: Create prompts that\nallow the AI to explore different solutions or\npaths. \nMeta-Prompting: Include instructions for the AI\nto evaluate or improve its own responses. \nPrompt Chaining: Use the output from one task\nas the input for the next task.',
#  'TASK 1.2\nBuild and Deploy Your Own App Using Claude.ai\nIn this activity we will create an app using\nclaude.ai by defining its purpose, features, and\nfunctionality. \nTopics suggestion:\nTravel Planner App\nTic-Tac Toe Game\nQuiz App\nSnake Game app\n',
#  'FOLLOW THE STEPS TO PERFORM THE\nACTIVITY:\nSTEP 1: Open the claude.ai website and create an\naccount.\nSTEP 2: After logging in, go to settings>>feature\npreview & enable the Latex rendering feature as\nshown in the image.(note: you only use this free tool 6\ntimes)\nSTEP 3: Choose a template or create from scratch.\n',
#  "STEP 4: Define the app's purpose and features\nin the prompts provided. (note : give a detailed\n& extensive prompt with all sort of features\ncolors of the App)\nSTEP 5: Customize the app using Claude’s\nsuggestions or by inputting your own\npreferences.\nSTEP 6: Review and deploy the app, testing its\nfunctionality."]

# %%
for page in pdf_text:
    print(page)
    print('/n----------------------------------------------------------------------------------------------------------------------------')
    print('/n')
    print('/n')
    print('/n')
    print('/n')
    print('/n')
# Out:
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
# TASK 1.1
# Make Your Own Prompt Library
# In this activity we’ll implement the prompting
# techniques that we learnt and apply to our
# daily tasksMastermind Workbook
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
# Step 1 : Identify Common Tasks
# List daily or routine tasks that can benefit from
# automation using AI. Examples: writing emails,
# summarizing documents, scheduling, etc.
# Step 2 : Create Base Prompts for Each Task
# For each task, develop a basic AI prompt.
# Context: Explain the background of the task.
# Task: State the specific action needed.
# Instruction: Clearly describe how to complete the task.
# Data: Identify any data required to perform the task.
# Role: Add a function (e.g., "As a project manager...") to
# enhance prompt accuracy.
# Step 3: Organize the Prompts
# Group prompts based on categories such as:
# Communication (e.g., emails, messaging)
# Productivity (e.g., meeting notes, scheduling)
# Research (e.g., summarizing articles, generating reports)
#   Fill the sheet with your details!FOLLOW THE STEPS TO
# PERFORM THE ACTIVITY:
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
#  STEP 4:  Refine the Prompts Using Prompting
# Techniques
# Zero-Shot Prompting: Start with no examples,
# and let the AI generate output based solely on
# the instruction.
# Few-Shot Prompting: Provide a few examples to
# guide the AI on how the output should look.
# Chain of Thought Prompting: Break down
# complex tasks into step-by-step instructions for
# the AI to follow.
# Tree of Thought Prompting: Create prompts that
# allow the AI to explore different solutions or
# paths.
# Meta-Prompting: Include instructions for the AI
# to evaluate or improve its own responses.
# Prompt Chaining: Use the output from one task
# as the input for the next task.
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
# TASK 1.2
# Build and Deploy Your Own App Using Claude.ai
# In this activity we will create an app using
# claude.ai by defining its purpose, features, and
# functionality.
# Topics suggestion:
# Travel Planner App
# Tic-Tac Toe Game
# Quiz App
# Snake Game app
#
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
# FOLLOW THE STEPS TO PERFORM THE
# ACTIVITY:
# STEP 1: Open the claude.ai website and create an
# account.
# STEP 2: After logging in, go to settings>>feature
# preview & enable the Latex rendering feature as
# shown in the image.(note: you only use this free tool 6
# times)
# STEP 3: Choose a template or create from scratch.
#
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
# STEP 4: Define the app's purpose and features
# in the prompts provided. (note : give a detailed
# & extensive prompt with all sort of features
# colors of the App)
# STEP 5: Customize the app using Claude’s
# suggestions or by inputting your own
# preferences.
# STEP 6: Review and deploy the app, testing its
# functionality.
# /n----------------------------------------------------------------------------------------------------------------------------
# /n
# /n
# /n
# /n
# /n
