# %%
#Import spaCy and load the language library
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
#Create a string that includes opening and closing quotation marks
mystring='"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
# create a doc object and explore tokens
doc=nlp(mystring)
for token in doc:
    print(token.text, end=" | ")
# Out:
# " | We | 're | moving | to | L.A. | ! | " |

# %%
# Prefixes, suffixes, and infixes

# %%
doc2=nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at https://oursite.com.!")
for t in doc2:
    print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# https://oursite.com
# .
# !

# %%
doc3=nlp(u"A 5km NYC cab ride costs $10.30")
for t in doc3:
    print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4=nlp(u"Let's visit St. Louis in the U.S. next year.")
for t in doc4:
    print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
#Count tokens
print(len(doc))
# Out:
# 8

# %%
#Count vocabulary
print(len(doc.vocab))
# Out:
# 794

# %%
#Tokens can be reterived by index postion and sliced
# Out:
# 're

# %%
doc5=nlp(u"It is better to give than to receive.")
#Retrive the third token
doc5[2]
# Out:
# better

# %%
# Retrieve three tokens from the middle
doc5[2:5]
# Out:
# better to give

# %%
# Retrieve the last four tokens
doc5[-4:]
# Out:
# than to receive.

# %%
# Tokens cannot be reassigned
doc6=nlp(u"My dinner was horrible.")
doc7=nlp(u"My dinner was delicious.")

# %%
# Try to change "My dinner was horrible." to "My dinner was delicious."
doc6[3]=doc7[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Try to change "My dinner was horrible." to "My dinner was delicious."
# ----> 2 doc6[3]=doc7[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
# Named entities

doc8=nlp(u"Apple to build the Hong Kong factory for $6 billion")

for token in doc8:
    print(token.text,end=" | ")

print("\n------")

for ent in doc8.ents:
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# Apple | to | build | the | Hong | Kong | factory | for | $ | 6 | billion |
# ------
# Apple - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# $6 billion - MONEY - Monetary values, including unit

# %%
# Length of named entities
len(doc8.ents)
# Out:
# 3

# %%
# Noun Chunks

doc9= nlp(u"Autonomous cars shift insurance liability toward manufacturers")
for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10=nlp(u"Red cars do not carry higher insurance rates.")
for chunk in doc10.noun_chunks:
    print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %%
doc11=nlp(u"He was a one-eyed, one-honored, flying, purple people-eater.")
for chunk in doc11.noun_chunks:
    print(chunk.text)
# Out:
# He
# a one-eyed, one-honored, flying, purple people-eater

# %%
# Built-in visualizers
# Visualizing the dependency parse
from spacy import displacy
doc=nlp(u"Apple is going to build a U.K. factory for $6 billion.")
displacy.render(doc,style="dep",jupyter=True,options={"distance": 115})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="80caecb779074d6aa949dc9cc3bbd706-0" class="displacy" width="1430" height="367.0" direction="ltr" style="max-width: none; height: 367.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="165">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="165">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="280">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="280">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="395">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="395">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="510">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="510">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="740">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="740">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="855">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="855">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="970">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="1085">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1085">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="1200">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="277.0">
#     <tspan class="displacy-word" fill="currentColor" x="1315">billion.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1315">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-0" stroke-width="2px" d="M70,232.0 C70,117.0 270.0,117.0 270.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,234.0 L62,222.0 78,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-1" stroke-width="2px" d="M185,232.0 C185,174.5 265.0,174.5 265.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M185,234.0 L177,222.0 193,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-2" stroke-width="2px" d="M415,232.0 C415,174.5 495.0,174.5 495.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M415,234.0 L407,222.0 423,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-3" stroke-width="2px" d="M300,232.0 C300,117.0 500.0,117.0 500.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M500.0,234.0 L508.0,222.0 492.0,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-4" stroke-width="2px" d="M645,232.0 C645,117.0 845.0,117.0 845.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645,234.0 L637,222.0 653,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-5" stroke-width="2px" d="M760,232.0 C760,174.5 840.0,174.5 840.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M760,234.0 L752,222.0 768,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-6" stroke-width="2px" d="M530,232.0 C530,59.5 850.0,59.5 850.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M850.0,234.0 L858.0,222.0 842.0,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb779074d6aa949dc9cc3bbd706-0-7" stroke-width="2px" d="M530,232.0 C530,2.0 970.0,2.0 970.0,232.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80caecb779074d6aa949dc9cc3bbd706-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M970.0,234.0 L978.0,222.0 962.0,222.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80caecb7

# %%
# Visualizing the entity recognizer
doc=nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.")
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  iPods for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>
